# %%
import pandas as pd

df = pd.read_csv("Resultados_Admision_2024I.csv", encoding="latin1")
df.columns = df.columns.str.replace("ï»¿", "", regex=False)
print(df.columns)
# Out:
# Index(['Modalidad', 'Escuela', 'CODIGO', 'APELLIDOS Y NOMBRES',
#        'ESCUELA PROFESIONAL', 'PUNTAJE FINAL', 'MERITO E.P ALCANZA VACANTE',
#        'OBSERVACI&OacuteN', 'ESCUELA SEGUNDA OPCIÃN'],
#       dtype='object')
